# %%
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations

# %%
df = pd.read_csv('8-all-at-once-window-4-2.txt')

def isEmptyRow(row):
    for i in range(3, len(row)):
        if row[i] != -999999:
            return False
    
    return True

envCounts = {'Alien-v0': [0]*len(pd.unique(df['tpgGen'])),
            'Asteroids-v0': [0]*len(pd.unique(df['tpgGen'])),
            'Atlantis-v0': [0]*len(pd.unique(df['tpgGen'])),
            'BankHeist-v0': [0]*len(pd.unique(df['tpgGen'])),
            'BattleZone-v0': [0]*len(pd.unique(df['tpgGen'])),
            'Bowling-v0': [0]*len(pd.unique(df['tpgGen'])),
            'Boxing-v0': [0]*len(pd.unique(df['tpgGen'])),
            'Centipede-v0': [0]*len(pd.unique(df['tpgGen']))}

for row in [df.iloc[i] for i in range(len(df)) if not isEmptyRow(df.iloc[i])]:
    for env in envCounts.keys():
        if row['score' + env] != -999999:
            envCounts[env][int(row['tpgGen']/10)-1] += 1

plt.figure(figsize=(12,6))
            
for env in sorted(envCounts.keys()):
    plt.plot(envCounts[env], label=env)
    
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
#plt.ylim(0,1)
plt.xlabel('Generation')
plt.ylabel('Number of Agents')
plt.title('Amount of Agents with Scores for Environment')
plt.show()

# %%
df = pd.read_csv('8-all-at-once-window-4-2.txt')

gamesPerAgent = {
            1: [0]*len(pd.unique(df['tpgGen'])),
            2: [0]*len(pd.unique(df['tpgGen'])),
            3: [0]*len(pd.unique(df['tpgGen'])),
            4: [0]*len(pd.unique(df['tpgGen'])),
            5: [0]*len(pd.unique(df['tpgGen'])),
            6: [0]*len(pd.unique(df['tpgGen'])),
            7: [0]*len(pd.unique(df['tpgGen'])),
            8: [0]*len(pd.unique(df['tpgGen']))}

envs = ['Alien-v0','Asteroids-v0','Atlantis-v0','BankHeist-v0',
            'BattleZone-v0','Bowling-v0','Boxing-v0','Centipede-v0']

for row in [df.iloc[i] for i in range(len(df)) if not isEmptyRow(df.iloc[i])]:
    gamesPlayed = 0
    for env in envs:
        if row['score' + env] != -999999:
            gamesPlayed += 1
            
    gamesPerAgent[gamesPlayed][int(row['tpgGen']/10)-1] += 1

plt.figure(figsize=(12,6))
    
for i in range(1,9):
    plt.plot(gamesPerAgent[i], label=str(i) + ' Games Played')
    
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
#plt.ylim(0,1)
plt.xlabel('Generation')
plt.ylabel('Number of Agents')
plt.title('Amount of Agents with Scores on Various Games')
plt.show()

# %%
print(isEmptyRow(df.iloc[372]))
# Out:
# True

# %%
df.tail(400)
# Out:
#       tpgGen  hoursElapsed  teamId  scoreAlien-v0  scoreAsteroids-v0  \
# 8689     210     62.010721   51990     266.666667        2020.000000
# 8690     210     62.010721   51994     253.333333        1820.000000
# 8691     210     62.010721   52203     296.666667        1860.000000
# 8692     210     62.010721   52264     236.666667        1540.000000
# 8693     210     62.010721   52280     286.666667        1566.666667
# 8694     210     62.010721   52476     256.666667     -999999.000000
# 8695     210     62.010721   52646     270.000000        1573.333333
# 8696     210     62.010721   52717     250.000000        1543.333333
# 8697     210     62.010721   52718     243.333333        2226.666667
# 8698     210     62.010721   52728     226.666667        2253.333333
# 8699     210     62.010721   52913     253.333333     -999999.000000
# 8700     210     62.010721   53000      30.000000        1720.000000
# 8701     210     62.010721   53030     310.000000     -999999.000000
# 8702     210     62.010721   53129     240.000000        1753.333333
# 8703     210     62.010721   53163     316.666667        1533.333333
# 8704     210     62.010721   53189     273.333333        2800.000000
# 8705     210     62.010721   53213     313.333333        1660.000000
# 8706     210     62.010721   53218     290.000000        1920.000000
# 8707     210     62.010721   53233     283.333333        1876.666667
# 8708     210     62.010721   53235     376.666667        2503.333333
# 8709     210     62.010721   53253     260.000000        1766.666667
# 8710     210     62.010721   53264     236.666667        1296.666667
# 8711     210     62.010721   53322     476.666667        1630.000000
# 8712     210     62.010721   53414     363.333333     -999999.000000
# 8713     210     62.010721   53462     353.333333     -999999.000000
# 8714     210     62.010721   53484     140.000000        2566.666667
# 8715     210     62.010721   53545     300.000000        1566.666667
# 8716     210     62.010721   53574     200.000000        1386.666667
# 8717     210     62.010721   53621      30.000000        1083.333333
# 8718     210     62.010721   53627     273.333333     -999999.000000
# ...      ...           ...     ...            ...                ...
# 9059     210     62.010726   54780 -999999.000000     -999999.000000
# 9060     210     62.010726   54781 -999999.000000     -999999.000000
# 9061     210     62.010727   54782 -999999.000000     -999999.000000
# 9062     210     62.010727   54783 -999999.000000     -999999.000000
# 9063     210     62.010727   54784 -999999.000000     -999999.000000
# 9064     210     62.010727   54785 -999999.000000     -999999.000000
# 9065     210     62.010727   54786 -999999.000000     -999999.000000
# 9066     210     62.010727   54787 -999999.000000     -999999.000000
# 9067     210     62.010727   54788 -999999.000000     -999999.000000
# 9068     210     62.010727   54789 -999999.000000     -999999.000000
# 9069     210     62.010727   54790 -999999.000000     -999999.000000
# 9070     210     62.010727   54791 -999999.000000     -999999.000000
# 9071     210     62.010727   54792 -999999.000000     -999999.000000
# 9072     210     62.010727   54793 -999999.000000     -999999.000000
# 9073     210     62.010727   54794 -999999.000000     -999999.000000
# 9074     210     62.010727   54795 -999999.000000     -999999.000000
# 9075     210     62.010727   54796 -999999.000000     -999999.000000
# 9076     210     62.010727   54797 -999999.000000     -999999.000000
# 9077     210     62.010727   54798 -999999.000000     -999999.000000
# 9078     210     62.010727   54799 -999999.000000     -999999.000000
# 9079     210     62.010727   54800 -999999.000000     -999999.000000
# 9080     210     62.010727   54801 -999999.000000     -999999.000000
# 9081     210     62.010727   54802 -999999.000000     -999999.000000
# 9082     210     62.010727   54803 -999999.000000     -999999.000000
# 9083     210     62.010727   54804 -999999.000000     -999999.000000
# 9084     210     62.010727   54805 -999999.000000     -999999.000000
# 9085     210     62.010727   54806 -999999.000000     -999999.000000
# 9086     210     62.010727   54807 -999999.000000     -999999.000000
# 9087     210     62.010727   54808 -999999.000000     -999999.000000
# 9088     210     62.010727   54809 -999999.000000     -999999.000000
#
#       scoreAtlantis-v0  scoreBankHeist-v0  scoreBattleZone-v0  \
# 8689      42166.666667          -999999.0        10000.000000
# 8690      38166.666667          -999999.0         9333.333333
# 8691      27700.000000          -999999.0         8000.000000
# 8692      44833.333333          -999999.0         8333.333333
# 8693      36566.666667          -999999.0        12333.333333
# 8694      29233.333333          -999999.0      -999999.000000
# 8695      42433.333333          -999999.0         8333.333333
# 8696      28066.666667          -999999.0         8000.000000
# 8697      28000.000000          -999999.0        10333.333333
# 8698      23166.666667          -999999.0         4666.666667
# 8699      41000.000000          -999999.0         8000.000000
# 8700       1500.000000          -999999.0        16333.333333
# 8701      30000.000000          -999999.0         8666.666667
# 8702      34633.333333          -999999.0         8666.666667
# 8703      56500.000000          -999999.0        10333.333333
# 8704      31000.000000          -999999.0         7666.666667
# 8705      29133.333333          -999999.0        10333.333333
# 8706      45100.000000          -999999.0        12000.000000
# 8707      41900.000000          -999999.0        11333.333333
# 8708      25066.666667          -999999.0         4000.000000
# 8709      55800.000000          -999999.0        12000.000000
# 8710      37766.666667          -999999.0        14000.000000
# 8711      25700.000000          -999999.0         8000.000000
# 8712      33733.333333          -999999.0         8333.333333
# 8713    -999999.000000          -999999.0         1333.333333
# 8714      39933.333333          -999999.0        14666.666667
# 8715      45733.333333          -999999.0        12333.333333
# 8716      54066.666667          -999999.0         5666.666667
# 8717      50200.000000          -999999.0        15666.666667
# 8718      27633.333333          -999999.0         7333.333333
# ...                ...                ...                 ...
# 9059    -999999.000000          -999999.0      -999999.000000
# 9060    -999999.000000          -999999.0      -999999.000000
# 9061    -999999.000000          -999999.0      -999999.000000
# 9062    -999999.000000          -999999.0      -999999.000000
# 9063    -999999.000000          -999999.0      -999999.000000
# 9064    -999999.000000          -999999.0      -999999.000000
# 9065    -999999.000000          -999999.0      -999999.000000
# 9066    -999999.000000          -999999.0      -999999.000000
# 9067    -999999.000000          -999999.0      -999999.000000
# 9068    -999999.000000          -999999.0      -999999.000000
# 9069    -999999.000000          -999999.0      -999999.000000
# 9070    -999999.000000          -999999.0      -999999.000000
# 9071    -999999.000000          -999999.0      -999999.000000
# 9072    -999999.000000          -999999.0      -999999.000000
# 9073    -999999.000000          -999999.0      -999999.000000
# 9074    -999999.000000          -999999.0      -999999.000000
# 9075    -999999.000000          -999999.0      -999999.000000
# 9076    -999999.000000          -999999.0      -999999.000000
# 9077    -999999.000000          -999999.0      -999999.000000
# 9078    -999999.000000          -999999.0      -999999.000000
# 9079    -999999.000000          -999999.0      -999999.000000
# 9080    -999999.000000          -999999.0      -999999.000000
# 9081    -999999.000000          -999999.0      -999999.000000
# 9082    -999999.000000          -999999.0      -999999.000000
# 9083    -999999.000000          -999999.0      -999999.000000
# 9084    -999999.000000          -999999.0      -999999.000000
# 9085    -999999.000000          -999999.0      -999999.000000
# 9086    -999999.000000          -999999.0      -999999.000000
# 9087    -999999.000000          -999999.0      -999999.000000
# 9088    -999999.000000          -999999.0      -999999.000000
#
#       scoreBowling-v0  scoreBoxing-v0  scoreCentipede-v0
# 8689        43.333333       -999999.0       15593.666667
# 8690        43.000000       -999999.0        7840.000000
# 8691        80.000000       -999999.0        9172.666667
# 8692        43.000000       -999999.0       10466.666667
# 8693        43.000000       -999999.0        7574.666667
# 8694        77.333333       -999999.0       11046.000000
# 8695        44.000000       -999999.0       10879.333333
# 8696        67.333333       -999999.0        9558.666667
# 8697        77.666667       -999999.0        7912.000000
# 8698        93.666667       -999999.0       13618.333333
# 8699        43.000000       -999999.0        9529.000000
# 8700         0.000000       -999999.0        8641.333333
# 8701        85.000000       -999999.0        6834.666667
# 8702        86.333333       -999999.0        9939.333333
# 8703        38.000000       -999999.0       12694.666667
# 8704        78.666667       -999999.0        9659.000000
# 8705        81.000000       -999999.0        9328.000000
# 8706        44.000000       -999999.0       12622.333333
# 8707        44.333333       -999999.0        8427.000000
# 8708        91.000000       -999999.0        3894.666667
# 8709        36.000000       -999999.0        6861.333333
# 8710        41.000000       -999999.0       10455.000000
# 8711        68.666667       -999999.0        9020.000000
# 8712        70.666667       -999999.0        9987.000000
# 8713        85.000000       -999999.0       10917.666667
# 8714        40.000000       -999999.0        5497.000000
# 8715        44.000000       -999999.0        7947.000000
# 8716         0.000000       -999999.0       11002.666667
# 8717        80.666667       -999999.0        7026.000000
# 8718        43.000000       -999999.0        7890.666667
# ...               ...             ...                ...
# 9059   -999999.000000       -999999.0     -999999.000000
# 9060   -999999.000000       -999999.0     -999999.000000
# 9061   -999999.000000       -999999.0     -999999.000000
# 9062   -999999.000000       -999999.0     -999999.000000
# 9063   -999999.000000       -999999.0     -999999.000000
# 9064   -999999.000000       -999999.0     -999999.000000
# 9065   -999999.000000       -999999.0     -999999.000000
# 9066   -999999.000000       -999999.0     -999999.000000
# 9067   -999999.000000       -999999.0     -999999.000000
# 9068   -999999.000000       -999999.0     -999999.000000
# 9069   -999999.000000       -999999.0     -999999.000000
# 9070   -999999.000000       -999999.0     -999999.000000
# 9071   -999999.000000       -999999.0     -999999.000000
# 9072   -999999.000000       -999999.0     -999999.000000
# 9073   -999999.000000       -999999.0     -999999.000000
# 9074   -999999.000000       -999999.0     -999999.000000
# 9075   -999999.000000       -999999.0     -999999.000000
# 9076   -999999.000000       -999999.0     -999999.000000
# 9077   -999999.000000       -999999.0     -999999.000000
# 9078   -999999.000000       -999999.0     -999999.000000
# 9079   -999999.000000       -999999.0     -999999.000000
# 9080   -999999.000000       -999999.0     -999999.000000
# 9081   -999999.000000       -999999.0     -999999.000000
# 9082   -999999.000000       -999999.0     -999999.000000
# 9083   -999999.000000       -999999.0     -999999.000000
# 9084   -999999.000000       -999999.0     -999999.000000
# 9085   -999999.000000       -999999.0     -999999.000000
# 9086   -999999.000000       -999999.0     -999999.000000
# 9087   -999999.000000       -999999.0     -999999.000000
# 9088   -999999.000000       -999999.0     -999999.000000
#
# [400 rows x 11 columns]

# %%
# for benchmarks

# on 18000 frame episodes, average of 10 episodes
soloRandomScores = {
     'Alien-v0': 164.0,'Asteroids-v0': 815.0,'Atlantis-v0': 21100.0,'BankHeist-v0': 17.0,
     'BattleZone-v0': 3300.0,'Bowling-v0': 20.2,'Boxing-v0': 2.4,'Centipede-v0': 2229.7,
     'ChopperCommand-v0': 660.0,'DoubleDunk-v0': -19.2,'FishingDerby-v0': -92.2,
     'Freeway-v0': 0.0,'Frostbite-v0': 53.0,'Gravitar-v0': 310.0,'Hero-v0': 1217.5,
     'IceHockey-v0': -10.9,'Jamesbond-v0': 25.0,'Kangaroo-v0': 60.0,'Krull-v0': 1479.8,
     'KungFuMaster-v0': 760.0,'MsPacman-v0': 246.0,'PrivateEye-v0': 40.0,
     'RoadRunner-v0': 20.0, 'Skiing-v0': -16270.7, 'Tennis-v0': -24.0,'TimePilot-v0': 3190.0,
     'UpNDown-v0': 422.0,'Venture-v0': 0.0,'WizardOfWor-v0': 750.0,'Zaxxon-v0': 0.0}

soloTpgScores = {
     'Alien-v0': 3382.7,'Asteroids-v0': 3050.7,'Atlantis-v0': 89653,'BankHeist-v0': 1051,
     'BattleZone-v0': 47233.4,'Bowling-v0': 223.7,'Boxing-v0': 76.5,'Centipede-v0': 34731.7,
     'ChopperCommand-v0': 7070,'DoubleDunk-v0': 2,'FishingDerby-v0': 49,
     'Freeway-v0': 28.9,'Frostbite-v0': 8144.4,'Gravitar-v0': 786.7,'Hero-v0': 16545.4,
     'IceHockey-v0': 10,'Jamesbond-v0': 3120,'Kangaroo-v0': 14780,'Krull-v0': 12850.4,
     'KungFuMaster-v0': 43353.4,'MsPacman-v0': 5156,'PrivateEye-v0': 15028.3,
     'RoadRunner-v0': 17410, 'Skiing-v0': 0, 'Tennis-v0': 1,'TimePilot-v0': 13540,
     'RoadRunner-v0': 17410,'Tennis-v0': 0,'TimePilot-v0': 13540,
     'UpNDown-v0': 34416,'Venture-v0': 576.7,'WizardOfWor-v0': 5196.7,'Zaxxon-v0': 6233.4}

# %%
df = pd.read_csv('8-all-at-once-window-4-2.txt')

envs = ['Alien-v0','Asteroids-v0','Atlantis-v0','BankHeist-v0',
            'BattleZone-v0','Bowling-v0','Boxing-v0','Centipede-v0']
envPairs = list(combinations(envs, 2))

gens = 4

envPoints = {}
for env in envs:
    envPoints[env] = [[]]*gens

for row in [df.iloc[i] for i in range(len(df)) if not isEmptyRow(df.iloc[i]) and df.iloc[i]['tpgGen']%50 == 0]:
    genNum = int(row['tpgGen'] / 50)-1
    for env in envs:
        envPoints[env][genNum].append((row['score'+env] - soloRandomScores[env])/
                                (soloTpgScores[env] - soloRandomScores[env]))

# %%
colors = ['C0', 'C1', 'C2', 'C3']

#plt.figure(figsize=(10,10))


for i, envPair in enumerate(envPairs):
    plt.ylim(0,1)
    plt.xlim(0,1)
    plt.xlabel(envPair[0])
    plt.ylabel(envPair[1])
    for gen in range(gens):
        plt.scatter(envPoints[envPair[0]][gen], envPoints[envPair[1]][gen], c=colors[gen], s=10)
        
    plt.show()
