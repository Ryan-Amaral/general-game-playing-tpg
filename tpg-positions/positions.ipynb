# %%
import pandas as pd

# %%
df = pd.read_csv('15-shrink-novir.txt')

mDict = {}
for thing in df.iloc[0,3:].tolist():
    mDict[thing] = {}

for thing in df.iloc[0,3:33].tolist():
    try:
        mDict[thing]['1st'] += 1
    except:
        mDict[thing]['1st'] = 1
        
for thing in df.iloc[0,33:63].tolist():
    try:
        mDict[thing]['2nd'] += 1
    except:
        mDict[thing]['2nd'] = 1
        
for thing in df.iloc[0,63:93].tolist():
    try:
        mDict[thing]['3rd'] += 1
    except:
        mDict[thing]['3rd'] = 1
        
for thing in df.iloc[0,93:123].tolist():
    try:
        mDict[thing]['4th'] += 1
    except:
        mDict[thing]['4th'] = 1
        
for thing in df.iloc[0,123:153].tolist():
    try:
        mDict[thing]['5th'] += 1
    except:
        mDict[thing]['5th'] = 1
        
for key in mDict:
    print(str(key) + ': ' + str(mDict[key]))
# Out:
# 16822: {'1st': 1}
# 10894: {'1st': 2}
# 16422: {'1st': 1}
# 16786: {'1st': 1}
# 15191: {'1st': 1}
# 17395: {'1st': 1}
# 14998: {'1st': 1}
# 12532: {'1st': 1}
# 9500: {'1st': 1}
# 1983: {'1st': 1}
# 4427: {'1st': 1, '2nd': 1}
# 827: {'1st': 1}
# 1703: {'1st': 1}
# 3962: {'1st': 1}
# 15961: {'1st': 1}
# 17202: {'1st': 1}
# 16630: {'1st': 1}
# 17468: {'1st': 1}
# 17252: {'1st': 1}
# 14918: {'1st': 1, '2nd': 1}
# 16707: {'1st': 1}
# 16148: {'1st': 1, '2nd': 1}
# 9184: {'1st': 1, '2nd': 1, '3rd': 1}
# 13927: {'1st': 1, '3rd': 1}
# 3936: {'1st': 1, '2nd': 1}
# 7644: {'1st': 1}
# 7795: {'1st': 1, '3rd': 1}
# 15514: {'1st': 1, '2nd': 1}
# 16585: {'1st': 1, '3rd': 1}
# 17099: {'2nd': 1}
# 16923: {'2nd': 1}
# 17544: {'2nd': 1}
# 12922: {'2nd': 2}
# 16184: {'2nd': 1}
# 3947: {'2nd': 3}
# 8451: {'2nd': 1}
# 17094: {'2nd': 2}
# 15788: {'2nd': 1}
# 16582: {'2nd': 1}
# 16123: {'2nd': 1}
# 14583: {'2nd': 1}
# 17090: {'2nd': 1}
# 14923: {'2nd': 1}
# 4642: {'2nd': 2}
# 12657: {'2nd': 1}
# 15858: {'2nd': 1}
# 15084: {'2nd': 1}
# 17126: {'2nd': 1}
# 15870: {'3rd': 3}
# 16493: {'3rd': 1}
# 14509: {'3rd': 1}
# 15878: {'3rd': 1}
# 16068: {'3rd': 1}
# 10951: {'3rd': 1}
# 6521: {'3rd': 1}
# 13269: {'3rd': 1}
# 17528: {'3rd': 1}

# %%
df = pd.read_csv('15-shrink-vir.txt')

mDict = {}
for thing in df.iloc[0,3:].tolist():
    mDict[thing] = {}

for thing in df.iloc[0,3:33].tolist():
    try:
        mDict[thing]['1st'] += 1
    except:
        mDict[thing]['1st'] = 1
        
for thing in df.iloc[0,33:63].tolist():
    try:
        mDict[thing]['2nd'] += 1
    except:
        mDict[thing]['2nd'] = 1
        
for thing in df.iloc[0,63:93].tolist():
    try:
        mDict[thing]['3rd'] += 1
    except:
        mDict[thing]['3rd'] = 1
        
for thing in df.iloc[0,93:123].tolist():
    try:
        mDict[thing]['4th'] += 1
    except:
        mDict[thing]['4th'] = 1
        
for thing in df.iloc[0,123:153].tolist():
    try:
        mDict[thing]['5th'] += 1
    except:
        mDict[thing]['5th'] = 1
        
for key in mDict:
    print(str(key) + ': ' + str(mDict[key]))
# Out:
# 830: {'1st': 1, '2nd': 2, '3rd': 2}
# 15994: {'1st': 1}
# 10265: {'1st': 2}
# 4209: {'1st': 3, '2nd': 1}
# 16935: {'1st': 1}
# 18250: {'1st': 1}
# 17983: {'1st': 1}
# 17162: {'1st': 1}
# 6079: {'1st': 1, '2nd': 1}
# 14596: {'1st': 1, '2nd': 1}
# 2477: {'1st': 1, '3rd': 2}
# 7056: {'1st': 1}
# 372: {'1st': 1, '2nd': 3}
# 17146: {'1st': 1}
# 1703: {'1st': 1, '2nd': 2, '3rd': 1}
# 17841: {'1st': 1}
# 15890: {'1st': 1}
# 9011: {'1st': 1}
# 16076: {'1st': 1, '3rd': 1}
# 16919: {'1st': 1, '3rd': 1}
# 3820: {'1st': 1}
# 17605: {'1st': 1}
# 3529: {'1st': 1}
# 5704: {'1st': 1}
# 7447: {'1st': 1}
# 17540: {'1st': 1}
# 18145: {'1st': 1}
# 13480: {'2nd': 1}
# 18210: {'2nd': 1}
# 14732: {'2nd': 1}
# 16423: {'2nd': 1}
# 13715: {'2nd': 3}
# 17631: {'2nd': 1}
# 6352: {'2nd': 1}
# 10442: {'2nd': 1}
# 14231: {'2nd': 1}
# 10664: {'2nd': 1}
# 15833: {'2nd': 1}
# 16230: {'2nd': 1}
# 16237: {'2nd': 1}
# 15794: {'2nd': 1}
# 18295: {'2nd': 1}
# 16081: {'2nd': 1}
# 4611: {'2nd': 1}
# 15596: {'2nd': 1}
# 18022: {'3rd': 1}
# 16922: {'3rd': 1}
# 15838: {'3rd': 1}
# 15847: {'3rd': 1}
# 16147: {'3rd': 1}
# 10923: {'3rd': 1}
# 15726: {'3rd': 1}
# 15949: {'3rd': 1}
