# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('8-all-at-once.txt')
df.head()
# Out:
#    tpgGen  hoursElapsed                                               envs  \
# 0       1      1.083582  Alien-v0/Asteroids-v0/Atlantis-v0/BankHeist-v0...
# 1       2      1.858212  Alien-v0/Asteroids-v0/Atlantis-v0/BankHeist-v0...
# 2       3      2.625376  Alien-v0/Asteroids-v0/Atlantis-v0/BankHeist-v0...
# 3       4      3.376680  Alien-v0/Asteroids-v0/Atlantis-v0/BankHeist-v0...
# 4       5      4.079454  Alien-v0/Asteroids-v0/Atlantis-v0/BankHeist-v0...
#
#    fitMin    fitMax    fitAvg  champSize  champUid  totalTeams  totalRootTeams
# 0     0.0  0.000000  0.000000          6       297         471             401
# 1     0.0  0.000000  0.000000          6       664         525             449
# 2     0.0  0.000000  0.000000          6       664         531             453
# 3     0.0  0.000000  0.000000         16      1077         531             441
# 4     0.0  0.047619  0.000108         16      1077         534             446

# %%
df = pd.read_csv('8-all-at-once.txt')

# 10 colors in cycle
plt.figure(figsize=(8,10))

plt.plot(df.fitMax)
        
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('TPG Max Fitness Scores per Generation')
plt.show()

# %%
df = pd.read_csv('8-all-at-once-window-4.txt')

envDfs = []
for envs in pd.unique(df.envs):
    envDfs.append(df.loc[df['envs'] == envs])

# 10 colors in cycle
plt.figure(figsize=(8,10))
cnt = 0
lineStyles = ['-', '--', '-.']
lsi = 0
for edf in envDfs:
    cnt += 1
    plt.plot(edf.fitMax, label=edf.envs.iloc[0]) 
             #label=edf.envs.iloc[0], ls=lineStyles[lsi])
    if cnt == 10:
        cnt = 0
        lsi += 1
        
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('TPG Max Fitness Scores per Generation')
plt.show()

# %%
df = pd.read_csv('8-merge.txt')

# 10 colors in cycle
plt.figure(figsize=(8,10))

plt.plot(df.fitMax)
        
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('TPG Max Fitness Scores per Generation')
plt.show()

# %%
df = pd.read_csv('8-merge-window-4.txt')

envDfs = []
for envs in pd.unique(df.envs):
    envDfs.append(df.loc[df['envs'] == envs])

# 10 colors in cycle
plt.figure(figsize=(8,10))
cnt = 0
lineStyles = ['-', '--', '-.']
lsi = 0
for edf in envDfs:
    cnt += 1
    plt.plot(edf.fitMax, label=edf.envs.iloc[0]) 
             #label=edf.envs.iloc[0], ls=lineStyles[lsi])
    if cnt == 10:
        cnt = 0
        lsi += 1
        
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('TPG Max Fitness Scores per Generation')
plt.show()
