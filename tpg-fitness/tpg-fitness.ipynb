# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('8-all-at-once.txt')

# 10 colors in cycle
plt.figure(figsize=(8,10))

plt.plot(df.fitMax)
        
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('TPG Max Fitness Scores per Generation')
plt.show()

# %%
df = pd.read_csv('8-all-at-once-window-2.txt')

envDfs = []
for envs in pd.unique(df.envs):
    envDfs.append(df.loc[df['envs'] == envs])

# 10 colors in cycle
plt.figure(figsize=(8,10))
cnt = 0
lineStyles = ['-', '--', '-.']
lsi = 0
for edf in envDfs:
    cnt += 1
    plt.plot(edf.fitMax, label=edf.envs.iloc[0]) 
             #label=edf.envs.iloc[0], ls=lineStyles[lsi])
    if cnt == 10:
        cnt = 0
        lsi += 1
        
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('TPG Max Fitness Scores per Generation')
plt.show()

# %%
df = pd.read_csv('8-all-at-once-window-4.txt')

envDfs = []
for envs in pd.unique(df.envs):
    envDfs.append(df.loc[df['envs'] == envs])

# 10 colors in cycle
plt.figure(figsize=(8,10))
cnt = 0
lineStyles = ['-', '--', '-.']
lsi = 0
for edf in envDfs:
    cnt += 1
    plt.plot(edf.fitMax, label=edf.envs.iloc[0]) 
             #label=edf.envs.iloc[0], ls=lineStyles[lsi])
    if cnt == 10:
        cnt = 0
        lsi += 1
        
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('TPG Max Fitness Scores per Generation')
plt.show()

# %%
df = pd.read_csv('8-merge.txt')

# 10 colors in cycle
plt.figure(figsize=(8,10))

plt.plot(df.fitMax)
        
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('TPG Max Fitness Scores per Generation')
plt.show()

# %%
df = pd.read_csv('8-merge-window-4.txt')

envDfs = []
for envs in pd.unique(df.envs):
    envDfs.append(df.loc[df['envs'] == envs])

# 10 colors in cycle
plt.figure(figsize=(8,10))
cnt = 0
lineStyles = ['-', '--', '-.']
lsi = 0
for edf in envDfs:
    cnt += 1
    plt.plot(edf.fitMax, label=edf.envs.iloc[0]) 
             #label=edf.envs.iloc[0], ls=lineStyles[lsi])
    if cnt == 10:
        cnt = 0
        lsi += 1
        
plt.legend(loc=2, bbox_to_anchor=(1.01, 1.0))
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('TPG Max Fitness Scores per Generation')
plt.show()
